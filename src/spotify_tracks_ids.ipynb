# %%
import pandas as pd

df_train = pd.read_csv("../data/music-genre-classification/train.csv")
df_train
# Out:
#                  Artist Name                             Track Name  \
# 0                 Bruno Mars  That's What I Like (feat. Gucci Mane)
# 1                     Boston                           Hitch a Ride
# 2              The Raincoats                     No Side to Fall In
# 3                       Deno             Lingo (feat. J.I & Chunkz)
# 4      Red Hot Chili Peppers      Nobody Weird Like Me - Remastered
# ...                      ...                                    ...
# 17991            Green-House                              Find Home
# 17992               Micatone                               All Gone
# 17993        Smash Hit Combo                           Peine perdue
# 17994                Beherit                         Salomon's Gate
# 17995         The Raconteurs                     Broken Boy Soldier
#
#        Popularity  danceability  energy   key  loudness  mode  speechiness  \
# ...

# %%
from pathlib import Path


def save_df_as_csv(df: pd.DataFrame, path: str):
    filepath = Path(path)
    filepath.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(filepath, index=False)


spotify_id_key = "spotify_id"
artist_name_key = "artist_name"
track_name_key = "track_name"
class_key = "class"

dic_spotify_ids_tracks = {
    spotify_id_key: [],
    artist_name_key: [],
    track_name_key: [],
    class_key: [],
}

df_spotify_ids = pd.DataFrame(dic_spotify_ids_tracks)
file_path = "../data/spotify-tracks-ids.csv"

try:
    df_spotify_ids = pd.read_csv(file_path)
except:
    save_df_as_csv(df_spotify_ids, file_path)

df_spotify_ids
# Out:
#                    spotify_id        artist_name  \
# 0      4bk6zQvr1tEokVjLJ7xZfz              Squid
# 1      2A110W6j3xAbTDsOXu4uN0      Kokomo Arnold
# 2      7vFaliU9GLPLNwyu2Kg0YT      Brynn Elliott
# 3      5jHL8tcDLiiXXKcGr4nkWk           LASTELLE
# 4      1oht5GevPN9t1T3kG1m1GO       James Taylor
# ...                       ...                ...
# 17759  0XBjcu4H7ZHD7nZykpX2cN  Movement At Night
# 17760  3A2OHirUAlQp2x73BJlEDA  Mike WiLL Made-It
# 17761  6qXBZGMoNHTVIebQDECoY9          The Maine
# 17762  68Cz5sfSKx1ugwoxJzLIHh              Kelpe
# 17763  3mYCd23hPxJW5okSvMoy3x        The Strokes
#
#                                               track_name  class
# 0                                               Paddling    6.0
# 1                          Mean Old Twister - Remastered    2.0
# 2                                       Letter To A Girl    9.0
# 3                                        A Letter Unread    8.0
# ...

# %%
artist_name_df_key = "Artist Name"
track_name_df_key = "Track Name"
class_df_key = "Class"

df_train_batch = df_train[[artist_name_df_key, track_name_df_key, class_df_key]]
df_train_batch.rename(
    columns={
        artist_name_df_key: artist_name_key,
        track_name_df_key: track_name_key,
        class_df_key: class_key,
    },
    inplace=True,
)
df_spotify_ids_batch = df_spotify_ids[[artist_name_key, track_name_key, class_key]]
df_batched = pd.concat([df_train_batch, df_spotify_ids_batch]).drop_duplicates(
    keep=False
)
df_batched
# Out:
# C:\Python38\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# Empty DataFrame
# Columns: [artist_name, track_name, class]
# Index: []

# %%
from service.spotify_service import SpotifyService

spotify_service = SpotifyService()

dic_spotify_ids_tracks = {
    spotify_id_key: [],
    artist_name_key: [],
    track_name_key: [],
    class_key: [],
}

rows, columns = df_batched.shape

for i in range(rows):
    row = df_batched.iloc[i]
    a_name = row[0]
    t_name = row[1]
    t_class = row[2]
    spotify_id = pd.NA
    try:
        spotify_id = spotify_service.get_spotify_track_id(t_name, a_name)
    except Exception as ex:
        print(ex)
        break
    dic_spotify_ids_tracks[spotify_id_key].append(spotify_id)
    dic_spotify_ids_tracks[artist_name_key].append(a_name)
    dic_spotify_ids_tracks[track_name_key].append(t_name)
    dic_spotify_ids_tracks[class_key].append(t_class)

# %%
df_spotify_tracks_ids = pd.DataFrame(dic_spotify_ids_tracks)
df_spotify_tracks_ids
# Out:
# Empty DataFrame
# Columns: [spotify_id, artist_name, track_name, class]
# Index: []

# %%
df_tracks_appended = df_spotify_tracks_ids.append(df_spotify_ids)
save_df_as_csv(df_tracks_appended, "../data/spotify-tracks-ids.csv")
