# %%
import pandas as pd

df_audio_features = pd.read_csv("../data/spotify-tracks-audio-features.csv")
df_audio_features
# Out:
#        acousticness                                       analysis_url  \
# 0          0.000429  https://api.spotify.com/v1/audio-analysis/4bk6...
# 1          0.995000  https://api.spotify.com/v1/audio-analysis/2A11...
# 2          0.296000  https://api.spotify.com/v1/audio-analysis/7vFa...
# 3          0.000307  https://api.spotify.com/v1/audio-analysis/5jHL...
# 4          0.766000  https://api.spotify.com/v1/audio-analysis/1oht...
# ...             ...                                                ...
# 18745      0.895000  https://api.spotify.com/v1/audio-analysis/3PFl...
# 18746      0.000063  https://api.spotify.com/v1/audio-analysis/0XBj...
# 18747      0.172000  https://api.spotify.com/v1/audio-analysis/3A2O...
# 18748      0.911000  https://api.spotify.com/v1/audio-analysis/68Cz...
# 18749      0.000003  https://api.spotify.com/v1/audio-analysis/3mYC...
#
#        danceability  duration_ms  energy              spotify_id  \
# ...

# %%
list(df_audio_features.columns)
# Out:
# ['acousticness',
#  'analysis_url',
#  'danceability',
#  'duration_ms',
#  'energy',
#  'spotify_id',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'mode',
#  'speechiness',
#  'tempo',
#  'time_signature',
#  'valence',
#  'artist_name',
#  'track_name',
#  'class']

# %%
df_values = df_audio_features[["spotify_id", "class"]].values
df_values
# Out:
# array([['4bk6zQvr1tEokVjLJ7xZfz', 6.0],
#        ['2A110W6j3xAbTDsOXu4uN0', 2.0],
#        ['7vFaliU9GLPLNwyu2Kg0YT', 9.0],
#        ...,
#        ['3A2OHirUAlQp2x73BJlEDA', 5.0],
#        ['68Cz5sfSKx1ugwoxJzLIHh', 1.0],
#        ['3mYCd23hPxJW5okSvMoy3x', 10.0]], dtype=object)

# %%
import seaborn as sns

df_corr = df_audio_features.corr()
sns.heatmap(df_corr)
# Out:
# <AxesSubplot:>
